# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f681bd82-50a1-450f-bd01-61542a7e9e53" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f681bd82-50a1-450f-bd01-61542a7e9e53">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Advertising.csv to Advertising.csv

# %%
#Linear regression example one variable

# Making the imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12.0, 9.0)

# %%
# Preprocessing Input data
data = pd.read_csv('Advertising.csv')
X = data.iloc[:, 1]
Y = data.iloc[:, 4]
plt.scatter(X, Y)
plt.show()

# %%
# Building the model
m = 0
c = 0


L = 0.00001 # The learning Rate
epochs = 50 # The number of iterations to perform gradient descent

n = float(len(X)) # Number of elements in X

# Performing Gradient Descent 
for i in range(epochs): 
    Y_pred = m*X + c  # The current predicted value of Y
    D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(Y - Y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c

print (m, c)
# Out:
# 0.08323873042694489 0.0022036485248894387

# %%
# Making predictions
Y_pred = m*X + c

plt.scatter(X, Y) 
plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red')  # regression line
plt.show()

# %%
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn import metrics
#from sklearn.cross_validation import train_test_split
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# read data into a DataFrame
dataxx = pd.read_csv('Advertising.csv', index_col=0)
dataxx.pop('Radio')
dataxx.pop('Newspaper')
dataxx.head()
# Out:
#       TV  Sales
# 1  230.1   22.1
# 2   44.5   10.4
# 3   17.2    9.3
# 4  151.5   18.5
# 5  180.8   12.9

# %%
### STATSMODELS ###

# create a fitted model
lm1 = smf.ols(formula='Sales ~ TV', data=dataxx).fit()

# print the coefficients
lm1.params
# Out:
# Intercept    7.032594
# TV           0.047537
# dtype: float64

# %%
### SCIKIT-LEARN ###

# create X and y
feature_cols = ['TV']
X = dataxx[feature_cols]
y = dataxx.Sales

# instantiate and fit
lm2 = LinearRegression()
lm2.fit(X, y)

# print the coefficients
print(lm2.intercept_)
print(lm2.coef_)
# Out:
# 7.032593549127695
# [0.04753664]

# %%
sns.pairplot(dataxx, x_vars=['TV'], y_vars='Sales', height=7, aspect=0.7, kind='reg')

# %%
# Preprocessing Input data
XX = dataxx.iloc[:, 0]
YY = dataxx.iloc[:, 1]
plt.scatter(XX, YY)
plt.show()

# %%
Y_predx = lm2.coef_*XX +  lm2.intercept_
#Y_predx = 1.4777440851889796*XX + 0.08893651996682016

plt.scatter(XX, YY) 
plt.plot([min(XX), max(XX)], [min(Y_predx), max(Y_predx)], color='red')  # regression line
plt.show()

# %%
#Y_predx = lm2.coef_*XX +  lm2.intercept_
Y_predx = 1.4777440851889796*XX + 0.08893651996682016

plt.scatter(XX, YY) 
plt.plot([min(XX), max(XX)], [min(Y_predx), max(Y_predx)], color='red')  # regression line
plt.show()

# %%
m = 0
c = 0


L = 0.00001  # The learning Rate
epochs = 50  # The number of iterations to perform gradient descent

n = float(len(XX)) # Number of elements in X

# Performing Gradient Descent 
for i in range(epochs): 
    Y_pred = m*XX + c  # The current predicted value of Y
    D_m = (-2/n) * sum(XX * (YY - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(YY - Y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c

print (m, c)
# Out:
# 0.08323873042694489 0.0022036485248894387

# %%
Y_pred = m*XX + c

plt.scatter(XX, YY) 
plt.plot([min(XX), max(XX)], [min(Y_pred), max(Y_pred)], color='red')  # regression line
plt.show()
